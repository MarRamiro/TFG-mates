# %%
import pandas as pd                                       #importing pandas
import numpy as np                                        #importing numpy
import copy                                               
import random
import matplotlib.pyplot as plt                           #importing matplotlib 
import seaborn as sns                                     #importing seaborn
from sklearn.model_selection import train_test_split      #importing scikit-learn's function for data splitting
from sklearn.linear_model import LinearRegression         #importing scikit-learn's linear regressor function
from sklearn.neural_network import MLPRegressor           #importing scikit-learn's neural network function
from sklearn.ensemble import GradientBoostingRegressor    #importing scikit-learn's gradient booster regressor function
from sklearn.metrics import mean_squared_error            #importing scikit-learn's root mean squared error function for model evaluation
from sklearn.model_selection import cross_validate        #improting scikit-learn's cross validation function

# %%
boxscores = pd.read_csv('https://raw.githubusercontent.com/Gurobi/modeling-examples/master/fantasy_basketball/boxscores_dataset.csv')     #load boxscores dataset
# running locally
# boxscores = pd.read_csv('boxscores_dataset.csv')     #load boxscores dataset
boxscores = boxscores[(boxscores.playMin>=3) | (boxscores.playMin.isnull())]

# %%
fig, (FGA, FGM, FTM, Min) = plt.subplots(1, 4, figsize=(14,5))
fig.tight_layout()

FGA.scatter(boxscores['playFGA'], boxscores['FantasyPoints'], c='blue', alpha = .2)
FGM.scatter(boxscores['playFGM'], boxscores['FantasyPoints'], c='lightblue', alpha = .2)
FTM.scatter(boxscores['playFTM'], boxscores['FantasyPoints'], c='coral', alpha = .2)
Min.scatter(boxscores['playMin'], boxscores['FantasyPoints'], c='purple', alpha = .2)

FGA.set_xlabel('Field Goal Attempts')
FGM.set_xlabel('Field Goals Made')
FTM.set_xlabel('Free Throws Made')
Min.set_xlabel('Minutes Played')

FGA.set_ylabel('Fantasy Points');

# %%
hplot = sns.histplot(boxscores['FantasyPoints'], color="blue", label="Fantasy Points", kde=True, stat="density", linewidth=0, bins=20)
hplot.set_xlabel("Fantasy Points", fontsize = 12)
hplot.set_ylabel("Density", fontsize = 12)
sns.set(rc={"figure.figsize":(14, 5)})

# %%
horizon=3

for column_name in ['playPTS','playAST','playTO','playSTL','playBLK','playTRB','playFGA','playFTA','play2P%','play3P%','playFT%','playMin','teamDayOff','FantasyPoints']:
    boxscores['moving' + column_name] = boxscores.groupby(['playDispNm'])[column_name].transform(lambda x: x.rolling(horizon, 1).mean().shift(1))                           #lagged moving average of numeric features

# %%
boxscores.dropna(subset = ["movingplayPTS"], inplace=True)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(boxscores[['movingplayPTS', 'movingplayAST','movingplayTO','movingplaySTL','movingplayBLK','movingplayTRB','movingplayFGA','movingplayFTA','movingplay2P%','movingplay3P%','movingplayFT%','movingplayMin','movingteamDayOff','movingFantasyPoints']].corr(),annot=True)
plt.show()

# %%
boxscores['dummyTeamLoc'] = pd.get_dummies(data=boxscores['teamLoc'],drop_first=True)    #1 if the game is a home game, 0 if it is an away game
boxscores['dummyplayStat'] = pd.get_dummies(data=boxscores['playStat'],drop_first=True)  #1 if the player starts, 0 if the player comes from the bench

# %%
forecasting_data = boxscores[boxscores.gmDate != '2017-12-25']  #for model training, we exclude observation on December 25, 2017

# %%
X = forecasting_data[['movingplayAST','movingplayTO','movingplaySTL','movingplayBLK','movingplayTRB','movingplayFTA','movingplayFT%','dummyplayStat']]  #select the features that will be used for model training
y = forecasting_data['FantasyPoints']  #target set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)      #dataset splitting

linear_regressor = LinearRegression()                                                         #load linear regressor
linear_regressor.fit(X_train, y_train)                                                        #train the linear regression model
linear_regression_validation = cross_validate(linear_regressor, X_train, y_train, cv=5, return_train_score=True, return_estimator=True)

mlp = MLPRegressor(hidden_layer_sizes=(5,5), activation='relu')                               #load neural network
mlp.fit(X_train,y_train)                                                                      #train the neural network with a ReLU function and two hidden layers with 5 nodes each
mlp_validation = cross_validate(mlp, X_train, y_train, cv=5, return_train_score=True, return_estimator=True)

gb = GradientBoostingRegressor()                                                              #load a gradient boosting regressor
gb.fit(X_train, y_train)                                                                      #train a gradient boosting model
gb_validation = cross_validate(gb, X_train, y_train, cv=5, return_train_score=True, return_estimator=True)

# %%
gb_validation['test_score']                            #print CV test score across each fold
# Out:
# array([0.50946508, 0.49911178, 0.48134545, 0.49757025, 0.50066142])

# %%
linear_regression_predictions = linear_regressor.predict(X_test)                              #make predictions based on the test set for the linear regression model
mlp_predictions = mlp.predict(X_test)                                                         #make predictions based on the test set for the neural network model
gb_predictions = gb.predict(X_test)                                                           #make predictions based on the test set for the gradient boosting model

linear_regression_mse = mean_squared_error(y_test, linear_regression_predictions)             #calculate the MSE for the linear regression model
mlp_mse = mean_squared_error(y_test, mlp_predictions)                                         #calculate the MSE for the neural network model
gb_mse = mean_squared_error(y_test, gb_predictions)                                           #calculate the MSE for the gradient boosting model

results = {'Linear Regression':[linear_regression_mse],'ReLU Neural Network':[mlp_mse],'Gradient Boosting Regressor':[gb_mse]}
modeling_results = pd.DataFrame(data=results,index=['MSE'])

modeling_results
# Out:
#      Linear Regression  ReLU Neural Network  Gradient Boosting Regressor
# MSE          91.077312            90.812011                    90.670528

# %%
fig, (LR, FNN, GBR) = plt.subplots(1, 3,figsize=(15,5));
fig.tight_layout()

LR.scatter(x = linear_regression_predictions, y = y_test - linear_regression_predictions,color='red',alpha=0.06)
FNN.scatter(x = mlp_predictions, y = y_test - mlp_predictions, color='green',alpha=0.06)
GBR.scatter(x = gb_predictions, y = y_test - gb_predictions, color='blue',alpha=0.06)

LR.set_xlabel('Linear Regression Predicted Fantasy Points')
FNN.set_xlabel('Neural Network Predicted Fantasy Points')
GBR.set_xlabel('Gradient Boosting Predicted Fantasy Points')

LR.set_ylabel('Linear Regression Residual')
FNN.set_ylabel('Neural Network Residual')
GBR.set_ylabel('Gradient Boosting Residual')
# Out:
# Text(968.0882352941177, 0.5, 'Gradient Boosting Residual')

# %%
gb_final = GradientBoostingRegressor(random_state=4)                                                             
gb_final.fit(X, y)   

optimization_dataset = boxscores
optimization_dataset['PredictedFantasyPoints'] = gb_final.predict(boxscores[['movingplayAST','movingplayTO','movingplaySTL','movingplayBLK','movingplayTRB','movingplayFTA','movingplayFT%','dummyplayStat']]) 

player_results = pd.read_csv('https://raw.githubusercontent.com/Gurobi/modeling-examples/master/fantasy_basketball/target_games.csv')
# player_results = pd.read_csv('target_games.csv')

predicted_fantasy_points = (
    optimization_dataset.query("gmDate == '2017-12-25'")
    [["playDispNm", "PredictedFantasyPoints"]]
)

player_results = pd.merge(
    left = player_results,
    right = predicted_fantasy_points,
    left_on = "Player",
    right_on = "playDispNm",
)

# %%
pd.set_option('display.expand_frame_repr', False)
player_results['Points/Salary Ratio'] = 1000*player_results['PredictedFantasyPoints']/player_results['Salary']    #we multiple the fantasy vs salary ratio by 1000 for better visualization
player_results.sort_values(by='PredictedFantasyPoints',ascending=False).head(5)
# Out:
#               Player Pos Team     Opp  Salary         playDispNm  PredictedFantasyPoints  Points/Salary Ratio
# 4        Joel Embiid   C  PHI   @ NYK    9500        Joel Embiid               51.313689             5.401441
# 0       James Harden  PG  HOU   @ OKC   11100       James Harden               48.809577             4.397259
# 1       LeBron James  SF  CLE   @ GSW   11000       LeBron James               48.149718             4.377247
# 2  Russell Westbrook  PG  OKC  vs HOU   10900  Russell Westbrook               44.007224             4.037360
# 3       Kevin Durant  SF  GSW  vs CLE   10500       Kevin Durant               43.438575             4.137007

# %%
indices = player_results.Player
points = dict(zip(indices, player_results.PredictedFantasyPoints))
salaries = dict(zip(indices, player_results.Salary))
positions = dict(zip(indices, player_results.Pos))

# %% [markdown]
# ### Restricciones

# %%
SALARY_CAP = 30000
POSITIONS = {"PG": 1, "SG": 1, "SF": 1, "PF": 1, "C": 1}

# %% [markdown]
# ### PARÁMETROS DEL PSO

# %%
N = 50  # Número de partículas
it_max = 300  # Iteraciones máximas
c1 = 1  # Peso cognitivo
c2 = 1  # Peso social
w = 0.3 # Parámetro de inercia

# %% [markdown]
# ### FUNCIÓN OBJETIVO: Ahora sin penalización

# %%
def fitness(team):
    """Calcula los fantasy points sin aplicar restricciones."""
    return sum(points[player] for player in team)

# %% [markdown]
# ### GENERACIÓN DEL EQUIPO VÁLIDO (Asegura restricciones antes de fitness)

# %%
def generate_valid_team():
    """Genera un equipo que cumple con todas las restricciones."""
    while True:
        valid_team = []
        for pos in POSITIONS:
            candidates = [p for p in indices if positions[p] == pos]
            valid_team.append(random.choice(candidates))
        
        total_salary = sum(salaries[player] for player in valid_team)
        if total_salary <= SALARY_CAP:
            return valid_team  # Solo devuelve el equipo si cumple con el salario

# %% [markdown]
# ### DEFINICIÓN DE PARTÍCULA

# %%
class Particle:
    def __init__(self):
        self.position = generate_valid_team()
        self.velocity = random.randint(1, 5)  # Inicializamos la velocidad (número de jugadores a cambiar) aleatoriamente entre 1 y 5
        self.best_position = self.position[:]
        self.best_fitness = fitness(self.position)

# %% [markdown]
# ### INICIALIZACIÓN DEL ENJAMBRE

# %%
particles = [Particle() for _ in range(N)]

# %% [markdown]
# ### Encontrar la mejor partícula global

# %%
gbest_particle = max(particles, key=lambda p: p.best_fitness)
gbest_position = gbest_particle.best_position
gbest_fitness = gbest_particle.best_fitness

# %% [markdown]
# ### PROCESO ITERATIVO DE PSO (Ahora con restricciones en `for`)

# %%
for it in range(it_max):
    for particle in particles:
        new_team = copy.deepcopy(particle.position)
        
        # Usamos la velocidad (número de cambios) para determinar cuántos jugadores cambiar
        indices_to_change = random.sample(range(len(new_team)), particle.velocity)

        for idx in indices_to_change:
            player = new_team[idx]
            pos_to_change = positions[player]
            
            # Filtrar candidatos para esa posición
            # esto lo podriamos tener como una variable ya hecha, como el el algortimo de GA, y en caso de p = player seleccionamos otro y ya
            candidates = [p for p in indices if positions[p] == pos_to_change and p != player]

            # Asegurar que siempre haya opciones válidas
            if not candidates:
                candidates = [p for p in indices if positions[p] == pos_to_change]

            # Aplicamos la actualización tipo PSO
            if random.random() < c1 / (c1 + c2):  # Influencia del mejor local
                new_team[idx] = particle.best_position[idx]
            elif random.random() < c2 / (c1 + c2):  # Influencia del mejor global
                new_team[idx] = gbest_position[idx]
            else:  # Exploración aleatoria
                new_team[idx] = random.choice(candidates)
            
        #print(new_team)

        # Verificamos restricciones ANTES de calcular fitness
        total_salary = sum(salaries[player] for player in new_team)
        if total_salary <= SALARY_CAP:
            new_fitness = fitness(new_team)
            #print(new_fitness)

            # Actualizar mejor posición local
            if new_fitness > particle.best_fitness:
                particle.best_position = new_team[:]
                particle.best_fitness = new_fitness

            # Actualizar mejor posición global
            if new_fitness > gbest_fitness:
                gbest_position = new_team[:]
                gbest_fitness = new_fitness
                
        # Actualizamos la velocidad de la partícula
        particle.velocity = int(w * particle.velocity + c1 * random.random() * (particle.best_fitness - fitness(new_team)) + c2 * random.random() * (gbest_fitness - fitness(new_team)))
        # Asegurarnos de que la velocidad esté dentro del rango de valores válidos (1 a 5 cambios)
        particle.velocity = max(1, min(particle.velocity, 5))
        

    print(f"Iteración {it + 1}: Mejor puntuación = {gbest_fitness}")
# Out:
# Iteración 1: Mejor puntuación = 148.89617880721903
# Iteración 2: Mejor puntuación = 148.89617880721903
# Iteración 3: Mejor puntuación = 168.0220890795023
# Iteración 4: Mejor puntuación = 168.0220890795023
# Iteración 5: Mejor puntuación = 168.0220890795023
# Iteración 6: Mejor puntuación = 168.0220890795023
# Iteración 7: Mejor puntuación = 168.0220890795023
# Iteración 8: Mejor puntuación = 168.0220890795023
# Iteración 9: Mejor puntuación = 168.0220890795023
# Iteración 10: Mejor puntuación = 168.0220890795023
# Iteración 11: Mejor puntuación = 168.0220890795023
# Iteración 12: Mejor puntuación = 169.78915278854086
# Iteración 13: Mejor puntuación = 169.78915278854086
# Iteración 14: Mejor puntuación = 169.78915278854086
# Iteración 15: Mejor puntuación = 169.78915278854086
# Iteración 16: Mejor puntuación = 169.78915278854086
# Iteración 17: Mejor puntuación = 169.78915278854086
# Iteración 18: Mejor puntuación = 169.78915278854086
# Iteración 19: Mejor puntuación = 169.78915278854086
# Iteración 20: Mejor puntuación = 169.78915278854086
# Iteración 21: Mejor puntuación = 169.78915278854086
# Iteración 22: Mejor puntuación = 170.71248975726505
# Iteración 23: Mejor puntuación = 170.71248975726505
# Iteración 24: Mejor puntuación = 170.71248975726505
# Iteración 25: Mejor puntuación = 170.71248975726505
# Iteración 26: Mejor puntuación = 171.91892913632242
# Iteración 27: Mejor puntuación = 171.91892913632242
# Iteración 28: Mejor puntuación = 171.91892913632242
# Iteración 29: Mejor puntuación = 171.91892913632242
# Iteración 30: Mejor puntuación = 171.91892913632242
# Iteración 31: Mejor puntuación = 171.91892913632242
# Iteración 32: Mejor puntuación = 171.91892913632242
# Iteración 33: Mejor puntuación = 171.91892913632242
# Iteración 34: Mejor puntuación = 171.91892913632242
# Iteración 35: Mejor puntuación = 171.91892913632242
# Iteración 36: Mejor puntuación = 171.91892913632242
# Iteración 37: Mejor puntuación = 171.91892913632242
# Iteración 38: Mejor puntuación = 171.91892913632242
# Iteración 39: Mejor puntuación = 171.91892913632242
# Iteración 40: Mejor puntuación = 171.91892913632242
# Iteración 41: Mejor puntuación = 171.91892913632242
# Iteración 42: Mejor puntuación = 171.91892913632242
# Iteración 43: Mejor puntuación = 171.91892913632242
# Iteración 44: Mejor puntuación = 171.91892913632242
# Iteración 45: Mejor puntuación = 171.91892913632242
# Iteración 46: Mejor puntuación = 171.91892913632242
# Iteración 47: Mejor puntuación = 171.91892913632242
# Iteración 48: Mejor puntuación = 171.91892913632242
# Iteración 49: Mejor puntuación = 171.91892913632242
# Iteración 50: Mejor puntuación = 171.91892913632242
# Iteración 51: Mejor puntuación = 171.91892913632242
# Iteración 52: Mejor puntuación = 171.91892913632242
# Iteración 53: Mejor puntuación = 171.91892913632242
# Iteración 54: Mejor puntuación = 171.91892913632242
# Iteración 55: Mejor puntuación = 171.91892913632242
# Iteración 56: Mejor puntuación = 171.91892913632242
# Iteración 57: Mejor puntuación = 171.91892913632242
# Iteración 58: Mejor puntuación = 171.91892913632242
# Iteración 59: Mejor puntuación = 171.91892913632242
# Iteración 60: Mejor puntuación = 171.91892913632242
# Iteración 61: Mejor puntuación = 171.91892913632242
# Iteración 62: Mejor puntuación = 171.91892913632242
# Iteración 63: Mejor puntuación = 171.91892913632242
# Iteración 64: Mejor puntuación = 171.91892913632242
# Iteración 65: Mejor puntuación = 171.91892913632242
# Iteración 66: Mejor puntuación = 171.91892913632242
# Iteración 67: Mejor puntuación = 171.91892913632242
# Iteración 68: Mejor puntuación = 171.91892913632242
# Iteración 69: Mejor puntuación = 171.91892913632242
# Iteración 70: Mejor puntuación = 171.91892913632242
# Iteración 71: Mejor puntuación = 171.91892913632242
# Iteración 72: Mejor puntuación = 171.91892913632242
# Iteración 73: Mejor puntuación = 171.91892913632242
# Iteración 74: Mejor puntuación = 171.91892913632242
# Iteración 75: Mejor puntuación = 171.91892913632242
# Iteración 76: Mejor puntuación = 171.91892913632242
# Iteración 77: Mejor puntuación = 171.91892913632242
# Iteración 78: Mejor puntuación = 171.91892913632242
# Iteración 79: Mejor puntuación = 171.91892913632242
# Iteración 80: Mejor puntuación = 171.91892913632242
# Iteración 81: Mejor puntuación = 171.91892913632242
# Iteración 82: Mejor puntuación = 171.91892913632242
# Iteración 83: Mejor puntuación = 171.91892913632242
# Iteración 84: Mejor puntuación = 171.91892913632242
# Iteración 85: Mejor puntuación = 171.91892913632242
# Iteración 86: Mejor puntuación = 171.91892913632242
# Iteración 87: Mejor puntuación = 171.91892913632242
# Iteración 88: Mejor puntuación = 171.91892913632242
# Iteración 89: Mejor puntuación = 171.91892913632242
# Iteración 90: Mejor puntuación = 171.91892913632242
# Iteración 91: Mejor puntuación = 171.91892913632242
# Iteración 92: Mejor puntuación = 171.91892913632242
# Iteración 93: Mejor puntuación = 171.91892913632242
# Iteración 94: Mejor puntuación = 171.91892913632242
# Iteración 95: Mejor puntuación = 171.91892913632242
# Iteración 96: Mejor puntuación = 171.91892913632242
# Iteración 97: Mejor puntuación = 171.91892913632242
# Iteración 98: Mejor puntuación = 171.91892913632242
# Iteración 99: Mejor puntuación = 171.91892913632242
# Iteración 100: Mejor puntuación = 171.91892913632242
# Iteración 101: Mejor puntuación = 171.91892913632242
# Iteración 102: Mejor puntuación = 171.91892913632242
# Iteración 103: Mejor puntuación = 171.91892913632242
# Iteración 104: Mejor puntuación = 171.91892913632242
# Iteración 105: Mejor puntuación = 171.91892913632242
# Iteración 106: Mejor puntuación = 171.91892913632242
# Iteración 107: Mejor puntuación = 171.91892913632242
# Iteración 108: Mejor puntuación = 171.91892913632242
# Iteración 109: Mejor puntuación = 171.91892913632242
# Iteración 110: Mejor puntuación = 171.91892913632242
# Iteración 111: Mejor puntuación = 171.91892913632242
# Iteración 112: Mejor puntuación = 171.91892913632242
# Iteración 113: Mejor puntuación = 171.91892913632242
# Iteración 114: Mejor puntuación = 171.91892913632242
# Iteración 115: Mejor puntuación = 171.91892913632242
# Iteración 116: Mejor puntuación = 171.91892913632242
# Iteración 117: Mejor puntuación = 171.91892913632242
# Iteración 118: Mejor puntuación = 171.91892913632242
# Iteración 119: Mejor puntuación = 171.91892913632242
# Iteración 120: Mejor puntuación = 171.91892913632242
# Iteración 121: Mejor puntuación = 171.91892913632242
# Iteración 122: Mejor puntuación = 171.91892913632242
# Iteración 123: Mejor puntuación = 171.91892913632242
# Iteración 124: Mejor puntuación = 171.91892913632242
# Iteración 125: Mejor puntuación = 171.91892913632242
# Iteración 126: Mejor puntuación = 171.91892913632242
# Iteración 127: Mejor puntuación = 171.91892913632242
# Iteración 128: Mejor puntuación = 171.91892913632242
# Iteración 129: Mejor puntuación = 171.91892913632242
# Iteración 130: Mejor puntuación = 171.91892913632242
# Iteración 131: Mejor puntuación = 171.91892913632242
# Iteración 132: Mejor puntuación = 171.91892913632242
# Iteración 133: Mejor puntuación = 171.91892913632242
# Iteración 134: Mejor puntuación = 171.91892913632242
# Iteración 135: Mejor puntuación = 171.91892913632242
# Iteración 136: Mejor puntuación = 171.91892913632242
# Iteración 137: Mejor puntuación = 171.91892913632242
# Iteración 138: Mejor puntuación = 171.91892913632242
# Iteración 139: Mejor puntuación = 171.91892913632242
# Iteración 140: Mejor puntuación = 171.91892913632242
# Iteración 141: Mejor puntuación = 171.91892913632242
# Iteración 142: Mejor puntuación = 171.91892913632242
# Iteración 143: Mejor puntuación = 171.91892913632242
# Iteración 144: Mejor puntuación = 171.91892913632242
# Iteración 145: Mejor puntuación = 171.91892913632242
# Iteración 146: Mejor puntuación = 171.91892913632242
# Iteración 147: Mejor puntuación = 171.91892913632242
# Iteración 148: Mejor puntuación = 171.91892913632242
# Iteración 149: Mejor puntuación = 171.91892913632242
# Iteración 150: Mejor puntuación = 171.91892913632242
# Iteración 151: Mejor puntuación = 171.91892913632242
# Iteración 152: Mejor puntuación = 171.91892913632242
# Iteración 153: Mejor puntuación = 171.91892913632242
# Iteración 154: Mejor puntuación = 171.91892913632242
# Iteración 155: Mejor puntuación = 171.91892913632242
# Iteración 156: Mejor puntuación = 171.91892913632242
# Iteración 157: Mejor puntuación = 171.91892913632242
# Iteración 158: Mejor puntuación = 171.91892913632242
# Iteración 159: Mejor puntuación = 171.91892913632242
# Iteración 160: Mejor puntuación = 171.91892913632242
# Iteración 161: Mejor puntuación = 171.91892913632242
# Iteración 162: Mejor puntuación = 171.91892913632242
# Iteración 163: Mejor puntuación = 171.91892913632242
# Iteración 164: Mejor puntuación = 171.91892913632242
# Iteración 165: Mejor puntuación = 171.91892913632242
# Iteración 166: Mejor puntuación = 171.91892913632242
# Iteración 167: Mejor puntuación = 171.91892913632242
# Iteración 168: Mejor puntuación = 171.91892913632242
# Iteración 169: Mejor puntuación = 171.91892913632242
# Iteración 170: Mejor puntuación = 171.91892913632242
# Iteración 171: Mejor puntuación = 171.91892913632242
# Iteración 172: Mejor puntuación = 171.91892913632242
# Iteración 173: Mejor puntuación = 171.91892913632242
# Iteración 174: Mejor puntuación = 171.91892913632242
# Iteración 175: Mejor puntuación = 171.91892913632242
# Iteración 176: Mejor puntuación = 171.91892913632242
# Iteración 177: Mejor puntuación = 171.91892913632242
# Iteración 178: Mejor puntuación = 171.91892913632242
# Iteración 179: Mejor puntuación = 171.91892913632242
# Iteración 180: Mejor puntuación = 171.91892913632242
# Iteración 181: Mejor puntuación = 171.91892913632242
# Iteración 182: Mejor puntuación = 171.91892913632242
# Iteración 183: Mejor puntuación = 171.91892913632242
# Iteración 184: Mejor puntuación = 171.91892913632242
# Iteración 185: Mejor puntuación = 171.91892913632242
# Iteración 186: Mejor puntuación = 171.91892913632242
# Iteración 187: Mejor puntuación = 171.91892913632242
# Iteración 188: Mejor puntuación = 171.91892913632242
# Iteración 189: Mejor puntuación = 171.91892913632242
# Iteración 190: Mejor puntuación = 171.91892913632242
# Iteración 191: Mejor puntuación = 171.91892913632242
# Iteración 192: Mejor puntuación = 171.91892913632242
# Iteración 193: Mejor puntuación = 171.91892913632242
# Iteración 194: Mejor puntuación = 171.91892913632242
# Iteración 195: Mejor puntuación = 171.91892913632242
# Iteración 196: Mejor puntuación = 171.91892913632242
# Iteración 197: Mejor puntuación = 171.91892913632242
# Iteración 198: Mejor puntuación = 171.91892913632242
# Iteración 199: Mejor puntuación = 171.91892913632242
# Iteración 200: Mejor puntuación = 171.91892913632242
# Iteración 201: Mejor puntuación = 171.91892913632242
# Iteración 202: Mejor puntuación = 171.91892913632242
# Iteración 203: Mejor puntuación = 171.91892913632242
# Iteración 204: Mejor puntuación = 171.91892913632242
# Iteración 205: Mejor puntuación = 171.91892913632242
# Iteración 206: Mejor puntuación = 171.91892913632242
# Iteración 207: Mejor puntuación = 171.91892913632242
# Iteración 208: Mejor puntuación = 171.91892913632242
# Iteración 209: Mejor puntuación = 171.91892913632242
# Iteración 210: Mejor puntuación = 171.91892913632242
# Iteración 211: Mejor puntuación = 171.91892913632242
# Iteración 212: Mejor puntuación = 171.91892913632242
# Iteración 213: Mejor puntuación = 171.91892913632242
# Iteración 214: Mejor puntuación = 171.91892913632242
# Iteración 215: Mejor puntuación = 171.91892913632242
# Iteración 216: Mejor puntuación = 171.91892913632242
# Iteración 217: Mejor puntuación = 171.91892913632242
# Iteración 218: Mejor puntuación = 171.91892913632242
# Iteración 219: Mejor puntuación = 171.91892913632242
# Iteración 220: Mejor puntuación = 171.91892913632242
# Iteración 221: Mejor puntuación = 171.91892913632242
# Iteración 222: Mejor puntuación = 171.91892913632242
# Iteración 223: Mejor puntuación = 171.91892913632242
# Iteración 224: Mejor puntuación = 171.91892913632242
# Iteración 225: Mejor puntuación = 171.91892913632242
# Iteración 226: Mejor puntuación = 171.91892913632242
# Iteración 227: Mejor puntuación = 171.91892913632242
# Iteración 228: Mejor puntuación = 171.91892913632242
# Iteración 229: Mejor puntuación = 171.91892913632242
# Iteración 230: Mejor puntuación = 171.91892913632242
# Iteración 231: Mejor puntuación = 171.91892913632242
# Iteración 232: Mejor puntuación = 171.91892913632242
# Iteración 233: Mejor puntuación = 171.91892913632242
# Iteración 234: Mejor puntuación = 171.91892913632242
# Iteración 235: Mejor puntuación = 171.91892913632242
# Iteración 236: Mejor puntuación = 171.91892913632242
# Iteración 237: Mejor puntuación = 171.91892913632242
# Iteración 238: Mejor puntuación = 171.91892913632242
# Iteración 239: Mejor puntuación = 171.91892913632242
# Iteración 240: Mejor puntuación = 171.91892913632242
# Iteración 241: Mejor puntuación = 171.91892913632242
# Iteración 242: Mejor puntuación = 171.91892913632242
# Iteración 243: Mejor puntuación = 171.91892913632242
# Iteración 244: Mejor puntuación = 171.91892913632242
# Iteración 245: Mejor puntuación = 171.91892913632242
# Iteración 246: Mejor puntuación = 171.91892913632242
# Iteración 247: Mejor puntuación = 171.91892913632242
# Iteración 248: Mejor puntuación = 171.91892913632242
# Iteración 249: Mejor puntuación = 171.91892913632242
# Iteración 250: Mejor puntuación = 171.91892913632242
# Iteración 251: Mejor puntuación = 171.91892913632242
# Iteración 252: Mejor puntuación = 171.91892913632242
# Iteración 253: Mejor puntuación = 171.91892913632242
# Iteración 254: Mejor puntuación = 171.91892913632242
# Iteración 255: Mejor puntuación = 171.91892913632242
# Iteración 256: Mejor puntuación = 171.91892913632242
# Iteración 257: Mejor puntuación = 171.91892913632242
# Iteración 258: Mejor puntuación = 171.91892913632242
# Iteración 259: Mejor puntuación = 171.91892913632242
# Iteración 260: Mejor puntuación = 171.91892913632242
# Iteración 261: Mejor puntuación = 171.91892913632242
# Iteración 262: Mejor puntuación = 171.91892913632242
# Iteración 263: Mejor puntuación = 171.91892913632242
# Iteración 264: Mejor puntuación = 171.91892913632242
# Iteración 265: Mejor puntuación = 171.91892913632242
# Iteración 266: Mejor puntuación = 171.91892913632242
# Iteración 267: Mejor puntuación = 171.91892913632242
# Iteración 268: Mejor puntuación = 171.91892913632242
# Iteración 269: Mejor puntuación = 171.91892913632242
# Iteración 270: Mejor puntuación = 171.91892913632242
# Iteración 271: Mejor puntuación = 171.91892913632242
# Iteración 272: Mejor puntuación = 171.91892913632242
# Iteración 273: Mejor puntuación = 171.91892913632242
# Iteración 274: Mejor puntuación = 171.91892913632242
# Iteración 275: Mejor puntuación = 171.91892913632242
# Iteración 276: Mejor puntuación = 171.91892913632242
# Iteración 277: Mejor puntuación = 171.91892913632242
# Iteración 278: Mejor puntuación = 171.91892913632242
# Iteración 279: Mejor puntuación = 171.91892913632242
# Iteración 280: Mejor puntuación = 171.91892913632242
# Iteración 281: Mejor puntuación = 171.91892913632242
# Iteración 282: Mejor puntuación = 171.91892913632242
# Iteración 283: Mejor puntuación = 171.91892913632242
# Iteración 284: Mejor puntuación = 171.91892913632242
# Iteración 285: Mejor puntuación = 171.91892913632242
# Iteración 286: Mejor puntuación = 171.91892913632242
# Iteración 287: Mejor puntuación = 171.91892913632242
# Iteración 288: Mejor puntuación = 171.91892913632242
# Iteración 289: Mejor puntuación = 171.91892913632242
# Iteración 290: Mejor puntuación = 171.91892913632242
# Iteración 291: Mejor puntuación = 171.91892913632242
# Iteración 292: Mejor puntuación = 171.91892913632242
# Iteración 293: Mejor puntuación = 171.91892913632242
# Iteración 294: Mejor puntuación = 171.91892913632242
# Iteración 295: Mejor puntuación = 171.91892913632242
# Iteración 296: Mejor puntuación = 171.91892913632242
# Iteración 297: Mejor puntuación = 171.91892913632242
# Iteración 298: Mejor puntuación = 171.91892913632242
# Iteración 299: Mejor puntuación = 171.91892913632242
# Iteración 300: Mejor puntuación = 171.91892913632242

# %% [markdown]
# ### RESULTADO FINAL

# %%
best_team = gbest_position
print("\nEquipo óptimo seleccionado:")
for player in best_team:
    print(f"{player} - Posición: {positions[player]}, FantasyPoints: {points[player]}, Salary: {salaries[player]}")
# Out:
# Equipo óptimo seleccionado:
# Jarrett Jack - Posición: PG, FantasyPoints: 27.780012412781506, Salary: 4600
# Trevor Ariza - Posición: SG, FantasyPoints: 26.354156526577885, Salary: 5000
# Markieff Morris - Posición: SF, FantasyPoints: 25.96558495634552, Salary: 4400
# Dario Saric - Posición: PF, FantasyPoints: 40.5054861101437, Salary: 6200
# Joel Embiid - Posición: C, FantasyPoints: 51.31368913047382, Salary: 9500
